# %%
import os
import librosa
import numpy as np
from scipy.signal import butter, sosfilt
from scipy.io import wavfile

def multiband_compression(y, sr, low_cutoff, high_cutoff, low_gain, high_gain):
    # Create a Butterworth high-pass filter
    order = 12
    nyquist = sr / 2
    norm_low_cutoff = low_cutoff / nyquist
    sos_highpass = butter(order, norm_low_cutoff, btype='high', analog=False, output='sos')

    # Apply the high-pass filter
    filtered_audio = sosfilt(sos_highpass, y)

    # Apply gain to different frequency bands
    low_band_indices = np.where(librosa.mel_frequencies(n_mels=filtered_audio.shape[0], fmin=0, fmax=sr/2) <= low_cutoff)[0]
    high_band_indices = np.where(librosa.mel_frequencies(n_mels=filtered_audio.shape[0], fmin=0, fmax=sr/2) > high_cutoff)[0]
    filtered_audio[low_band_indices] *= low_gain
    filtered_audio[high_band_indices] *= high_gain

    return filtered_audio

# Define parameters for multiband compression
low_cutoff = 300
high_cutoff = 3000
low_gain = 0.05
high_gain = 1.2

# Set input and output directories
input_dir = 'audio'
output_dir = 'audio_edited'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        # Load the audio file
        audio_file = os.path.join(input_dir, filename)
        y, sr = librosa.load(audio_file)

        # Apply multiband compression
        filtered_audio = multiband_compression(y, sr, low_cutoff, high_cutoff, low_gain, high_gain)

        # Export the filtered audio to a new file
        output_filename = os.path.splitext(filename)[0] + '.mp3'
        export_file = os.path.join(output_dir, output_filename)
        wavfile.write(export_file, sr, np.int16(filtered_audio * 32767))

        print(f"Filtered audio saved as {export_file}")

print("Note: Converting to MP3 may result in further quality loss due to re-encoding.")
print("You can now use a speech-to-text tool like Whisper to convert the filtered audio to text.")
# Out:
# Filtered audio saved as audio_edited\300_AUDIO.mp3
# Filtered audio saved as audio_edited\301_AUDIO.mp3
# Filtered audio saved as audio_edited\302_AUDIO.mp3
# Filtered audio saved as audio_edited\303_AUDIO.mp3
# Filtered audio saved as audio_edited\304_AUDIO.mp3
# Filtered audio saved as audio_edited\305_AUDIO.mp3
# Filtered audio saved as audio_edited\306_AUDIO.mp3
# Filtered audio saved as audio_edited\307_AUDIO.mp3
# Filtered audio saved as audio_edited\308_AUDIO.mp3
# Filtered audio saved as audio_edited\309_AUDIO.mp3
# Filtered audio saved as audio_edited\310_AUDIO.mp3
# Filtered audio saved as audio_edited\311_AUDIO.mp3
# Filtered audio saved as audio_edited\312_AUDIO.mp3
# Filtered audio saved as audio_edited\313_AUDIO.mp3
# Filtered audio saved as audio_edited\314_AUDIO.mp3
# Filtered audio saved as audio_edited\315_AUDIO.mp3
# Filtered audio saved as audio_edited\316_AUDIO.mp3
# Filtered audio saved as audio_edited\317_AUDIO.mp3
# Filtered audio saved as audio_edited\318_AUDIO.mp3
# Filtered audio saved as audio_edited\319_AUDIO.mp3
# Filtered audio saved as audio_edited\320_AUDIO.mp3
# Filtered audio saved as audio_edited\321_AUDIO.mp3
# Filtered audio saved as audio_edited\322_AUDIO.mp3
# Filtered audio saved as audio_edited\323_AUDIO.mp3
# Filtered audio saved as audio_edited\324_AUDIO.mp3
# Filtered audio saved as audio_edited\325_AUDIO.mp3
# Filtered audio saved as audio_edited\326_AUDIO.mp3
# Filtered audio saved as audio_edited\327_AUDIO.mp3
# Filtered audio saved as audio_edited\328_AUDIO.mp3
# Filtered audio saved as audio_edited\329_AUDIO.mp3
# Filtered audio saved as audio_edited\330_AUDIO.mp3
# Filtered audio saved as audio_edited\331_AUDIO.mp3
# Filtered audio saved as audio_edited\332_AUDIO.mp3
# Filtered audio saved as audio_edited\333_AUDIO.mp3
# Filtered audio saved as audio_edited\334_AUDIO.mp3
# Filtered audio saved as audio_edited\335_AUDIO.mp3
# Filtered audio saved as audio_edited\336_AUDIO.mp3
# Filtered audio saved as audio_edited\337_AUDIO.mp3
# Filtered audio saved as audio_edited\338_AUDIO.mp3
# Filtered audio saved as audio_edited\339_AUDIO.mp3
# Filtered audio saved as audio_edited\340_AUDIO.mp3
# Filtered audio saved as audio_edited\341_AUDIO.mp3
# Filtered audio saved as audio_edited\343_AUDIO.mp3
# Filtered audio saved as audio_edited\344_AUDIO.mp3
# Filtered audio saved as audio_edited\345_AUDIO.mp3
# Filtered audio saved as audio_edited\346_AUDIO.mp3
# Filtered audio saved as audio_edited\347_AUDIO.mp3
# Filtered audio saved as audio_edited\348_AUDIO.mp3
# Filtered audio saved as audio_edited\349_AUDIO.mp3
# Filtered audio saved as audio_edited\350_AUDIO.mp3
# Filtered audio saved as audio_edited\351_AUDIO.mp3
# Filtered audio saved as audio_edited\352_AUDIO.mp3
# Filtered audio saved as audio_edited\353_AUDIO.mp3
# Filtered audio saved as audio_edited\354_AUDIO.mp3
# Filtered audio saved as audio_edited\355_AUDIO.mp3
# Filtered audio saved as audio_edited\356_AUDIO.mp3
# Filtered audio saved as audio_edited\357_AUDIO.mp3
# Filtered audio saved as audio_edited\358_AUDIO.mp3
# Filtered audio saved as audio_edited\359_AUDIO.mp3
# Filtered audio saved as audio_edited\360_AUDIO.mp3
# Filtered audio saved as audio_edited\361_AUDIO.mp3
# Filtered audio saved as audio_edited\362_AUDIO.mp3
# Filtered audio saved as audio_edited\363_AUDIO.mp3
# Filtered audio saved as audio_edited\364_AUDIO.mp3
# Filtered audio saved as audio_edited\365_AUDIO.mp3
# Filtered audio saved as audio_edited\366_AUDIO.mp3
# Filtered audio saved as audio_edited\367_AUDIO.mp3
# Filtered audio saved as audio_edited\368_AUDIO.mp3
# Filtered audio saved as audio_edited\369_AUDIO.mp3
# Filtered audio saved as audio_edited\370_AUDIO.mp3
# Filtered audio saved as audio_edited\371_AUDIO.mp3
# Filtered audio saved as audio_edited\372_AUDIO.mp3
# Filtered audio saved as audio_edited\373_AUDIO.mp3
# Filtered audio saved as audio_edited\374_AUDIO.mp3
# Filtered audio saved as audio_edited\375_AUDIO.mp3
# Filtered audio saved as audio_edited\376_AUDIO.mp3
# Filtered audio saved as audio_edited\377_AUDIO.mp3
# Filtered audio saved as audio_edited\378_AUDIO.mp3
# Filtered audio saved as audio_edited\379_AUDIO.mp3
# Filtered audio saved as audio_edited\380_AUDIO.mp3
# Filtered audio saved as audio_edited\381_AUDIO.mp3
# Filtered audio saved as audio_edited\382_AUDIO.mp3
# Filtered audio saved as audio_edited\383_AUDIO.mp3
# Filtered audio saved as audio_edited\384_AUDIO.mp3
# Filtered audio saved as audio_edited\385_AUDIO.mp3
# Filtered audio saved as audio_edited\386_AUDIO.mp3
# Filtered audio saved as audio_edited\387_AUDIO.mp3
# Filtered audio saved as audio_edited\388_AUDIO.mp3
# Filtered audio saved as audio_edited\389_AUDIO.mp3
# Filtered audio saved as audio_edited\390_AUDIO.mp3
# Filtered audio saved as audio_edited\391_AUDIO.mp3
# Filtered audio saved as audio_edited\392_AUDIO.mp3
# Filtered audio saved as audio_edited\393_AUDIO.mp3
# Filtered audio saved as audio_edited\395_AUDIO.mp3
# Filtered audio saved as audio_edited\396_AUDIO.mp3
# Filtered audio saved as audio_edited\397_AUDIO.mp3
# Filtered audio saved as audio_edited\399_AUDIO.mp3
# Filtered audio saved as audio_edited\400_AUDIO.mp3
# Filtered audio saved as audio_edited\401_AUDIO.mp3
# Filtered audio saved as audio_edited\402_AUDIO.mp3
# Filtered audio saved as audio_edited\403_AUDIO.mp3
# Filtered audio saved as audio_edited\404_AUDIO.mp3
# Filtered audio saved as audio_edited\405_AUDIO.mp3
# Filtered audio saved as audio_edited\406_AUDIO.mp3
# Filtered audio saved as audio_edited\407_AUDIO.mp3
# Filtered audio saved as audio_edited\408_AUDIO.mp3
# Filtered audio saved as audio_edited\409_AUDIO.mp3
# Filtered audio saved as audio_edited\410_AUDIO.mp3
# Filtered audio saved as audio_edited\411_AUDIO.mp3
# Filtered audio saved as audio_edited\412_AUDIO.mp3
# Filtered audio saved as audio_edited\413_AUDIO.mp3
# Filtered audio saved as audio_edited\414_AUDIO.mp3
# Filtered audio saved as audio_edited\415_AUDIO.mp3
# Filtered audio saved as audio_edited\416_AUDIO.mp3
# Filtered audio saved as audio_edited\417_AUDIO.mp3
# Filtered audio saved as audio_edited\418_AUDIO.mp3
# Filtered audio saved as audio_edited\419_AUDIO.mp3
# Filtered audio saved as audio_edited\420_AUDIO.mp3
# Filtered audio saved as audio_edited\421_AUDIO.mp3
# Filtered audio saved as audio_edited\422_AUDIO.mp3
# Filtered audio saved as audio_edited\423_AUDIO.mp3
# Filtered audio saved as audio_edited\424_AUDIO.mp3
# Filtered audio saved as audio_edited\425_AUDIO.mp3
# Filtered audio saved as audio_edited\426_AUDIO.mp3
# Filtered audio saved as audio_edited\427_AUDIO.mp3
# Filtered audio saved as audio_edited\428_AUDIO.mp3
# Filtered audio saved as audio_edited\429_AUDIO.mp3
# Filtered audio saved as audio_edited\430_AUDIO.mp3
# Filtered audio saved as audio_edited\431_AUDIO.mp3
# Filtered audio saved as audio_edited\432_AUDIO.mp3
# Filtered audio saved as audio_edited\433_AUDIO.mp3
# Filtered audio saved as audio_edited\434_AUDIO.mp3
# Filtered audio saved as audio_edited\435_AUDIO.mp3
# Filtered audio saved as audio_edited\436_AUDIO.mp3
# Filtered audio saved as audio_edited\437_AUDIO.mp3
# Filtered audio saved as audio_edited\438_AUDIO.mp3
# Filtered audio saved as audio_edited\439_AUDIO.mp3
# Filtered audio saved as audio_edited\440_AUDIO.mp3
# Filtered audio saved as audio_edited\441_AUDIO.mp3
# Filtered audio saved as audio_edited\442_AUDIO.mp3
# Filtered audio saved as audio_edited\443_AUDIO.mp3
# Filtered audio saved as audio_edited\444_AUDIO.mp3
# Filtered audio saved as audio_edited\445_AUDIO.mp3
# Filtered audio saved as audio_edited\446_AUDIO.mp3
# Filtered audio saved as audio_edited\447_AUDIO.mp3
# Filtered audio saved as audio_edited\448_AUDIO.mp3
# Filtered audio saved as audio_edited\449_AUDIO.mp3
# Filtered audio saved as audio_edited\450_AUDIO.mp3
# Filtered audio saved as audio_edited\451_AUDIO.mp3
# Filtered audio saved as audio_edited\452_AUDIO.mp3
# Filtered audio saved as audio_edited\453_AUDIO.mp3
# Filtered audio saved as audio_edited\454_AUDIO.mp3
# Filtered audio saved as audio_edited\455_AUDIO.mp3
# Filtered audio saved as audio_edited\456_AUDIO.mp3
# Filtered audio saved as audio_edited\457_AUDIO.mp3
# Filtered audio saved as audio_edited\458_AUDIO.mp3
# Filtered audio saved as audio_edited\459_AUDIO.mp3
# Filtered audio saved as audio_edited\461_AUDIO.mp3
# Filtered audio saved as audio_edited\462_AUDIO.mp3
# Filtered audio saved as audio_edited\463_AUDIO.mp3
# Filtered audio saved as audio_edited\464_AUDIO.mp3
# Filtered audio saved as audio_edited\465_AUDIO.mp3
# Filtered audio saved as audio_edited\466_AUDIO.mp3
# Filtered audio saved as audio_edited\467_AUDIO.mp3
# Filtered audio saved as audio_edited\468_AUDIO.mp3
# Filtered audio saved as audio_edited\469_AUDIO.mp3
# Filtered audio saved as audio_edited\470_AUDIO.mp3
# Filtered audio saved as audio_edited\471_AUDIO.mp3
# Filtered audio saved as audio_edited\472_AUDIO.mp3
# Filtered audio saved as audio_edited\473_AUDIO.mp3
# Filtered audio saved as audio_edited\474_AUDIO.mp3
# Filtered audio saved as audio_edited\475_AUDIO.mp3
# Filtered audio saved as audio_edited\476_AUDIO.mp3
# Filtered audio saved as audio_edited\477_AUDIO.mp3
# Filtered audio saved as audio_edited\478_AUDIO.mp3
# Filtered audio saved as audio_edited\479_AUDIO.mp3
# Filtered audio saved as audio_edited\480_AUDIO.mp3
# Filtered audio saved as audio_edited\481_AUDIO.mp3
# Filtered audio saved as audio_edited\482_AUDIO.mp3
# Filtered audio saved as audio_edited\483_AUDIO.mp3
# Filtered audio saved as audio_edited\484_AUDIO.mp3
# Filtered audio saved as audio_edited\485_AUDIO.mp3
# Filtered audio saved as audio_edited\486_AUDIO.mp3
# Filtered audio saved as audio_edited\487_AUDIO.mp3
# Filtered audio saved as audio_edited\488_AUDIO.mp3
# Filtered audio saved as audio_edited\489_AUDIO.mp3
# Filtered audio saved as audio_edited\490_AUDIO.mp3
# Filtered audio saved as audio_edited\491_AUDIO.mp3
# Filtered audio saved as audio_edited\492_AUDIO.mp3
# Filtered audio saved as audio_edited\600_AUDIO.mp3
# Filtered audio saved as audio_edited\601_AUDIO.mp3
# Filtered audio saved as audio_edited\602_AUDIO.mp3
# Filtered audio saved as audio_edited\603_AUDIO.mp3
# Filtered audio saved as audio_edited\604_AUDIO.mp3
# Filtered audio saved as audio_edited\605_AUDIO.mp3
# Filtered audio saved as audio_edited\606_AUDIO.mp3
# Filtered audio saved as audio_edited\607_AUDIO.mp3
# Filtered audio saved as audio_edited\608_AUDIO.mp3
# Filtered audio saved as audio_edited\609_AUDIO.mp3
# Filtered audio saved as audio_edited\612_AUDIO.mp3
# Filtered audio saved as audio_edited\615_AUDIO.mp3
# Filtered audio saved as audio_edited\617_AUDIO.mp3
# Filtered audio saved as audio_edited\618_AUDIO.mp3
# Filtered audio saved as audio_edited\619_AUDIO.mp3
# Filtered audio saved as audio_edited\620_AUDIO.mp3
# Filtered audio saved as audio_edited\622_AUDIO.mp3
# Filtered audio saved as audio_edited\623_AUDIO.mp3
# Filtered audio saved as audio_edited\624_AUDIO.mp3
# Filtered audio saved as audio_edited\625_AUDIO.mp3
# Filtered audio saved as audio_edited\626_AUDIO.mp3
# Filtered audio saved as audio_edited\627_AUDIO.mp3
# Filtered audio saved as audio_edited\628_AUDIO.mp3
# Filtered audio saved as audio_edited\629_AUDIO.mp3
# Filtered audio saved as audio_edited\631_AUDIO.mp3
# Filtered audio saved as audio_edited\632_AUDIO.mp3
# Filtered audio saved as audio_edited\633_AUDIO.mp3
# Filtered audio saved as audio_edited\634_AUDIO.mp3
# Filtered audio saved as audio_edited\635_AUDIO.mp3
# Filtered audio saved as audio_edited\636_AUDIO.mp3
# Filtered audio saved as audio_edited\637_AUDIO.mp3
# Filtered audio saved as audio_edited\638_AUDIO.mp3
# Filtered audio saved as audio_edited\640_AUDIO.mp3
# Filtered audio saved as audio_edited\641_AUDIO.mp3
# Filtered audio saved as audio_edited\649_AUDIO.mp3
# Filtered audio saved as audio_edited\650_AUDIO.mp3
# Filtered audio saved as audio_edited\651_AUDIO.mp3
# Filtered audio saved as audio_edited\652_AUDIO.mp3
# Filtered audio saved as audio_edited\653_AUDIO.mp3
# Filtered audio saved as audio_edited\654_AUDIO.mp3
# Filtered audio saved as audio_edited\655_AUDIO.mp3
# Filtered audio saved as audio_edited\656_AUDIO.mp3
# Filtered audio saved as audio_edited\657_AUDIO.mp3
# Filtered audio saved as audio_edited\658_AUDIO.mp3
# Filtered audio saved as audio_edited\659_AUDIO.mp3
# Filtered audio saved as audio_edited\660_AUDIO.mp3
# Filtered audio saved as audio_edited\661_AUDIO.mp3
# Filtered audio saved as audio_edited\662_AUDIO.mp3
# Filtered audio saved as audio_edited\663_AUDIO.mp3
# Filtered audio saved as audio_edited\664_AUDIO.mp3
# Filtered audio saved as audio_edited\666_AUDIO.mp3
# Filtered audio saved as audio_edited\667_AUDIO.mp3
# Filtered audio saved as audio_edited\669_AUDIO.mp3
# Filtered audio saved as audio_edited\670_AUDIO.mp3
# Filtered audio saved as audio_edited\673_AUDIO.mp3
# Filtered audio saved as audio_edited\676_AUDIO.mp3
# Filtered audio saved as audio_edited\677_AUDIO.mp3
# Filtered audio saved as audio_edited\679_AUDIO.mp3
# Filtered audio saved as audio_edited\680_AUDIO.mp3
# Filtered audio saved as audio_edited\682_AUDIO.mp3
# Filtered audio saved as audio_edited\683_AUDIO.mp3
# Filtered audio saved as audio_edited\684_AUDIO.mp3
# Filtered audio saved as audio_edited\687_AUDIO.mp3
# Filtered audio saved as audio_edited\688_AUDIO.mp3
# Filtered audio saved as audio_edited\689_AUDIO.mp3
# Filtered audio saved as audio_edited\691_AUDIO.mp3
# Filtered audio saved as audio_edited\692_AUDIO.mp3
# Filtered audio saved as audio_edited\693_AUDIO.mp3
# Filtered audio saved as audio_edited\695_AUDIO.mp3
# Filtered audio saved as audio_edited\696_AUDIO.mp3
# Filtered audio saved as audio_edited\697_AUDIO.mp3
# Filtered audio saved as audio_edited\698_AUDIO.mp3
# Filtered audio saved as audio_edited\699_AUDIO.mp3
# Filtered audio saved as audio_edited\702_AUDIO.mp3
# Filtered audio saved as audio_edited\703_AUDIO.mp3
# Filtered audio saved as audio_edited\705_AUDIO.mp3
# Filtered audio saved as audio_edited\707_AUDIO.mp3
# Filtered audio saved as audio_edited\708_AUDIO.mp3
# Filtered audio saved as audio_edited\709_AUDIO.mp3
# Filtered audio saved as audio_edited\710_AUDIO.mp3
# Filtered audio saved as audio_edited\712_AUDIO.mp3
# Filtered audio saved as audio_edited\713_AUDIO.mp3
# Filtered audio saved as audio_edited\715_AUDIO.mp3
# Filtered audio saved as audio_edited\716_AUDIO.mp3
# Filtered audio saved as audio_edited\717_AUDIO.mp3
# Filtered audio saved as audio_edited\718_AUDIO.mp3
# Note: Converting to MP3 may result in further quality loss due to re-encoding.
# You can now use a speech-to-text tool like Whisper to convert the filtered audio to text.

# %%
import os
import whisper
from whisper.utils import get_writer

# Load the Whisper model
model = whisper.load_model("tiny")

# Set input and output directories
input_dir = 'audio_edited'
output_dir = 'text'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.mp3'):
        # Load the audio file
        audio_file = os.path.join(input_dir, filename)

        # Transcribe the audio using Whisper
        result = model.transcribe(audio_file)

        # Save the transcription as a TXT file
        output_filename = os.path.splitext(filename)[0] + '.txt'
        output_file = os.path.join(output_dir, output_filename)
        with open(output_file, "w", encoding="utf-8") as txt:
            txt.write(result["text"])

        print(f"Transcription saved as {output_file}")
# Out:
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:06<00:00, 10.8MiB/s]
# Transcription saved as text\300_AUDIO.txt
# Transcription saved as text\301_AUDIO.txt
# Transcription saved as text\302_AUDIO.txt
# Transcription saved as text\303_AUDIO.txt
# Transcription saved as text\304_AUDIO.txt
# Transcription saved as text\305_AUDIO.txt
# Transcription saved as text\306_AUDIO.txt
# Transcription saved as text\307_AUDIO.txt
# Transcription saved as text\308_AUDIO.txt
# Transcription saved as text\309_AUDIO.txt
# Transcription saved as text\310_AUDIO.txt
# Transcription saved as text\311_AUDIO.txt
# Transcription saved as text\312_AUDIO.txt
# Transcription saved as text\313_AUDIO.txt
# Transcription saved as text\314_AUDIO.txt
# Transcription saved as text\315_AUDIO.txt
# Transcription saved as text\316_AUDIO.txt
# Transcription saved as text\317_AUDIO.txt
# Transcription saved as text\318_AUDIO.txt
# Transcription saved as text\319_AUDIO.txt
# Transcription saved as text\320_AUDIO.txt
# Transcription saved as text\321_AUDIO.txt
# Transcription saved as text\322_AUDIO.txt
# Transcription saved as text\323_AUDIO.txt
# Transcription saved as text\324_AUDIO.txt
# Transcription saved as text\325_AUDIO.txt
# Transcription saved as text\326_AUDIO.txt
# Transcription saved as text\327_AUDIO.txt
# Transcription saved as text\328_AUDIO.txt
# Transcription saved as text\329_AUDIO.txt
# Transcription saved as text\330_AUDIO.txt
# Transcription saved as text\331_AUDIO.txt
# Transcription saved as text\332_AUDIO.txt
# Transcription saved as text\333_AUDIO.txt
# Transcription saved as text\334_AUDIO.txt
# Transcription saved as text\335_AUDIO.txt
# Transcription saved as text\336_AUDIO.txt
# Transcription saved as text\337_AUDIO.txt
# Transcription saved as text\338_AUDIO.txt
# Transcription saved as text\339_AUDIO.txt
# Transcription saved as text\340_AUDIO.txt
# Transcription saved as text\341_AUDIO.txt
# Transcription saved as text\343_AUDIO.txt
# Transcription saved as text\344_AUDIO.txt
# Transcription saved as text\345_AUDIO.txt
# Transcription saved as text\346_AUDIO.txt
# Transcription saved as text\347_AUDIO.txt
# Transcription saved as text\348_AUDIO.txt
# Transcription saved as text\349_AUDIO.txt
# Transcription saved as text\350_AUDIO.txt
# Transcription saved as text\351_AUDIO.txt
# Transcription saved as text\352_AUDIO.txt
# Transcription saved as text\353_AUDIO.txt
# Transcription saved as text\354_AUDIO.txt
# Transcription saved as text\355_AUDIO.txt
# Transcription saved as text\356_AUDIO.txt
# Transcription saved as text\357_AUDIO.txt
# Transcription saved as text\358_AUDIO.txt
# Transcription saved as text\359_AUDIO.txt
# Transcription saved as text\360_AUDIO.txt
# Transcription saved as text\361_AUDIO.txt
# Transcription saved as text\362_AUDIO.txt
# Transcription saved as text\363_AUDIO.txt
# Transcription saved as text\364_AUDIO.txt
# Transcription saved as text\365_AUDIO.txt
# Transcription saved as text\366_AUDIO.txt
# Transcription saved as text\367_AUDIO.txt
# Transcription saved as text\368_AUDIO.txt
# Transcription saved as text\369_AUDIO.txt
# Transcription saved as text\370_AUDIO.txt
# Transcription saved as text\371_AUDIO.txt
# Transcription saved as text\372_AUDIO.txt
# Transcription saved as text\373_AUDIO.txt
# Transcription saved as text\374_AUDIO.txt
# Transcription saved as text\375_AUDIO.txt
# Transcription saved as text\376_AUDIO.txt
# Transcription saved as text\377_AUDIO.txt
# Transcription saved as text\378_AUDIO.txt
# Transcription saved as text\379_AUDIO.txt
# Transcription saved as text\380_AUDIO.txt
# Transcription saved as text\381_AUDIO.txt
# Transcription saved as text\382_AUDIO.txt
# Transcription saved as text\383_AUDIO.txt
# Transcription saved as text\384_AUDIO.txt
# Transcription saved as text\385_AUDIO.txt
# Transcription saved as text\386_AUDIO.txt
# Transcription saved as text\387_AUDIO.txt
# Transcription saved as text\388_AUDIO.txt
# Transcription saved as text\389_AUDIO.txt
# Transcription saved as text\390_AUDIO.txt
# Transcription saved as text\391_AUDIO.txt
# Transcription saved as text\392_AUDIO.txt
# Transcription saved as text\393_AUDIO.txt
# Transcription saved as text\395_AUDIO.txt
# Transcription saved as text\396_AUDIO.txt
# Transcription saved as text\397_AUDIO.txt
# Transcription saved as text\399_AUDIO.txt
# Transcription saved as text\400_AUDIO.txt
# Transcription saved as text\401_AUDIO.txt
# Transcription saved as text\402_AUDIO.txt
# Transcription saved as text\403_AUDIO.txt
# Transcription saved as text\404_AUDIO.txt
# Transcription saved as text\405_AUDIO.txt
# Transcription saved as text\406_AUDIO.txt
# Transcription saved as text\407_AUDIO.txt
# Transcription saved as text\408_AUDIO.txt
# Transcription saved as text\409_AUDIO.txt
# Transcription saved as text\410_AUDIO.txt
# Transcription saved as text\411_AUDIO.txt
# Transcription saved as text\412_AUDIO.txt
# Transcription saved as text\413_AUDIO.txt
# Transcription saved as text\414_AUDIO.txt
# Transcription saved as text\415_AUDIO.txt
# Transcription saved as text\416_AUDIO.txt
# Transcription saved as text\417_AUDIO.txt
# Transcription saved as text\418_AUDIO.txt
# Transcription saved as text\419_AUDIO.txt
# Transcription saved as text\420_AUDIO.txt
# Transcription saved as text\421_AUDIO.txt
# Transcription saved as text\422_AUDIO.txt
# Transcription saved as text\423_AUDIO.txt
# Transcription saved as text\424_AUDIO.txt
# Transcription saved as text\425_AUDIO.txt
# Transcription saved as text\426_AUDIO.txt
# Transcription saved as text\427_AUDIO.txt
# Transcription saved as text\428_AUDIO.txt
# Transcription saved as text\429_AUDIO.txt
# Transcription saved as text\430_AUDIO.txt
# Transcription saved as text\431_AUDIO.txt
# Transcription saved as text\432_AUDIO.txt
# Transcription saved as text\433_AUDIO.txt
# Transcription saved as text\434_AUDIO.txt
# Transcription saved as text\435_AUDIO.txt
# Transcription saved as text\436_AUDIO.txt
# Transcription saved as text\437_AUDIO.txt
# Transcription saved as text\438_AUDIO.txt
# Transcription saved as text\439_AUDIO.txt
# Transcription saved as text\440_AUDIO.txt
# Transcription saved as text\441_AUDIO.txt
# Transcription saved as text\442_AUDIO.txt
# Transcription saved as text\443_AUDIO.txt
# Transcription saved as text\444_AUDIO.txt
# Transcription saved as text\445_AUDIO.txt
# Transcription saved as text\446_AUDIO.txt
# Transcription saved as text\447_AUDIO.txt
# Transcription saved as text\448_AUDIO.txt
# Transcription saved as text\449_AUDIO.txt
# Transcription saved as text\450_AUDIO.txt
# Transcription saved as text\451_AUDIO.txt
# Transcription saved as text\452_AUDIO.txt
# Transcription saved as text\453_AUDIO.txt
# Transcription saved as text\454_AUDIO.txt
# Transcription saved as text\455_AUDIO.txt
# Transcription saved as text\456_AUDIO.txt
# Transcription saved as text\457_AUDIO.txt
# Transcription saved as text\458_AUDIO.txt
# Transcription saved as text\459_AUDIO.txt
# Transcription saved as text\461_AUDIO.txt
# Transcription saved as text\462_AUDIO.txt
# Transcription saved as text\463_AUDIO.txt
# Transcription saved as text\464_AUDIO.txt
# Transcription saved as text\465_AUDIO.txt
# Transcription saved as text\466_AUDIO.txt
# Transcription saved as text\467_AUDIO.txt
# Transcription saved as text\468_AUDIO.txt
# Transcription saved as text\469_AUDIO.txt
# Transcription saved as text\470_AUDIO.txt
# Transcription saved as text\471_AUDIO.txt
# Transcription saved as text\472_AUDIO.txt
# Transcription saved as text\473_AUDIO.txt
# Transcription saved as text\474_AUDIO.txt
# Transcription saved as text\475_AUDIO.txt
# Transcription saved as text\476_AUDIO.txt
# Transcription saved as text\477_AUDIO.txt
# Transcription saved as text\478_AUDIO.txt
# Transcription saved as text\479_AUDIO.txt
# Transcription saved as text\480_AUDIO.txt
# Transcription saved as text\481_AUDIO.txt
# Transcription saved as text\482_AUDIO.txt
# Transcription saved as text\483_AUDIO.txt
# Transcription saved as text\484_AUDIO.txt
# Transcription saved as text\485_AUDIO.txt
# Transcription saved as text\486_AUDIO.txt
# Transcription saved as text\487_AUDIO.txt

# %%
import os
import whisper
from whisper.utils import get_writer

# Load the Whisper model
model = whisper.load_model("tiny")

# Set input and output directories
input_dir = 'audio_edited'
output_dir = 'text'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Flag to indicate when to start processing
start_processing = False

# Loop through all files in the input directory
for filename in sorted(os.listdir(input_dir)):
    if filename == '488_AUDIO.mp3':
        start_processing = True  # Start processing when 488_AUDIO.mp3 is found
    if start_processing and filename.endswith('.mp3'):
        # Load the audio file
        audio_file = os.path.join(input_dir, filename)

        # Transcribe the audio using Whisper
        result = model.transcribe(audio_file)

        # Save the transcription as a TXT file
        output_filename = os.path.splitext(filename)[0] + '.txt'
        output_file = os.path.join(output_dir, output_filename)
        with open(output_file, "w", encoding="utf-8") as txt:
            txt.write(result["text"])

        print(f"Transcription saved as {output_file}")
# Out:
# Transcription saved as text\488_AUDIO.txt
# Transcription saved as text\489_AUDIO.txt
# Transcription saved as text\490_AUDIO.txt
# Transcription saved as text\491_AUDIO.txt
# Transcription saved as text\492_AUDIO.txt
# Transcription saved as text\600_AUDIO.txt
# Transcription saved as text\601_AUDIO.txt
# Transcription saved as text\602_AUDIO.txt
# Transcription saved as text\603_AUDIO.txt
# Transcription saved as text\604_AUDIO.txt
# Transcription saved as text\605_AUDIO.txt
# Transcription saved as text\606_AUDIO.txt
# Transcription saved as text\607_AUDIO.txt
# Transcription saved as text\608_AUDIO.txt
# Transcription saved as text\609_AUDIO.txt
# Transcription saved as text\612_AUDIO.txt
# Transcription saved as text\615_AUDIO.txt
# Transcription saved as text\617_AUDIO.txt
# Transcription saved as text\618_AUDIO.txt
# Transcription saved as text\619_AUDIO.txt
# Transcription saved as text\620_AUDIO.txt
# Transcription saved as text\622_AUDIO.txt
# Transcription saved as text\623_AUDIO.txt
# Transcription saved as text\624_AUDIO.txt
# Transcription saved as text\625_AUDIO.txt
# Transcription saved as text\626_AUDIO.txt
# Transcription saved as text\627_AUDIO.txt
# Transcription saved as text\628_AUDIO.txt
# Transcription saved as text\629_AUDIO.txt
# Transcription saved as text\631_AUDIO.txt
# Transcription saved as text\632_AUDIO.txt
# Transcription saved as text\633_AUDIO.txt
# Transcription saved as text\634_AUDIO.txt
# Transcription saved as text\635_AUDIO.txt
# Transcription saved as text\636_AUDIO.txt
# Transcription saved as text\637_AUDIO.txt
# Transcription saved as text\638_AUDIO.txt
# Transcription saved as text\640_AUDIO.txt
# Transcription saved as text\641_AUDIO.txt
# Transcription saved as text\649_AUDIO.txt
# Transcription saved as text\650_AUDIO.txt
# Transcription saved as text\651_AUDIO.txt
# Transcription saved as text\652_AUDIO.txt
# Transcription saved as text\653_AUDIO.txt
# Transcription saved as text\654_AUDIO.txt
# Transcription saved as text\655_AUDIO.txt
# Transcription saved as text\656_AUDIO.txt
# Transcription saved as text\657_AUDIO.txt
# Transcription saved as text\658_AUDIO.txt
# Transcription saved as text\659_AUDIO.txt
# Transcription saved as text\660_AUDIO.txt
# Transcription saved as text\661_AUDIO.txt
# Transcription saved as text\662_AUDIO.txt
# Transcription saved as text\663_AUDIO.txt
# Transcription saved as text\664_AUDIO.txt
# Transcription saved as text\666_AUDIO.txt
# Transcription saved as text\667_AUDIO.txt
# Transcription saved as text\669_AUDIO.txt
# Transcription saved as text\670_AUDIO.txt
# Transcription saved as text\673_AUDIO.txt
# Transcription saved as text\676_AUDIO.txt
# Transcription saved as text\677_AUDIO.txt
# Transcription saved as text\679_AUDIO.txt
# Transcription saved as text\680_AUDIO.txt
# Transcription saved as text\682_AUDIO.txt
# Transcription saved as text\683_AUDIO.txt
# Transcription saved as text\684_AUDIO.txt
# Transcription saved as text\687_AUDIO.txt
# Transcription saved as text\688_AUDIO.txt
# Transcription saved as text\689_AUDIO.txt
# Transcription saved as text\691_AUDIO.txt
# Transcription saved as text\692_AUDIO.txt
# Transcription saved as text\693_AUDIO.txt
# Transcription saved as text\695_AUDIO.txt
# Transcription saved as text\696_AUDIO.txt
# Transcription saved as text\697_AUDIO.txt
# Transcription saved as text\698_AUDIO.txt
# Transcription saved as text\699_AUDIO.txt
# Transcription saved as text\702_AUDIO.txt
# Transcription saved as text\703_AUDIO.txt
# Transcription saved as text\705_AUDIO.txt
# Transcription saved as text\707_AUDIO.txt
# Transcription saved as text\708_AUDIO.txt
# Transcription saved as text\709_AUDIO.txt
# Transcription saved as text\710_AUDIO.txt
# Transcription saved as text\712_AUDIO.txt
# Transcription saved as text\713_AUDIO.txt
# Transcription saved as text\715_AUDIO.txt
# Transcription saved as text\716_AUDIO.txt
# Transcription saved as text\717_AUDIO.txt
# Transcription saved as text\718_AUDIO.txt
